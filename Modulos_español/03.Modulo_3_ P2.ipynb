# %% [markdown]
# # Módulo 3: Identificación de linajes
#
# ¡Bienvenido al módulo!
#
# Como ha realizado antes:
#
# 1.) Haga clic en el archivo en la esquina superior izquierda y seleccione Guardar una copia en la unidad
# Sus cambios no se guardarán si no hace este paso.
#
# 2.) Haga clic en el nombre del libro de trabajo en la esquina superior izquierda y reemplace "Copia de" con su nombre completo.

# %% [markdown]
# Por favor escribe:
# `` `` ``
# Imprimir ("Sí, he hecho el paso 1")
# `` `` ``
# En el bloque de código a continuación, luego ejecute haciendo clic en el icono "Triángulo"/"Play" en ese bloque

# %%
#Bloque

# %% [markdown]
# Por favor escribe:
# `` `` ``
# Imprimir ("Sí, he completado el paso 2")
# `` `` ``
# En el bloque de código a continuación, luego ejecute haciendo clic en el icono "Triángulo"/"Play" en ese bloque

# %%
#Bloque

# %% [markdown]
# ## Ejercicio
#
# En esta tarea, se espera que recupere archivos FASTQ de un proyecto de secuenciación del genoma realizado en Hong Kong. El BioProject que contiene estas lecturas está depositado en ENA EBI: https://www.ebi.ac.uk/ena/browser/view/PRJNA627286
#
#
# 1. Hay cinco biosamples en el BioProject, usa el comando wget para descargar todos los archivos FASTQ (archivos FASTQ únicos de ONT)
# 2. Instala condacolab
# 3. Instala el Pipeline Artic de EPI2ME
# 4. Construye genomas de consenso a partir de los archivos FASTQ utilizando EPI2ME
# 5. Identifica las linajes en los aislados
# 6. Reporta tus hallazgos
